// %% [markdown]
// # Setup

// %%
!go mod init k8swithgo
// Out:
// go: creating new go.mod: module k8swithgo

// %%
!go get "k8s.io/client-go/kubernetes@latest"

// %% [markdown]
// # client-go
//
// ## kubernetes
//
// core clientset for API access

// %%
import (
    "context"
    "fmt"
    "os"
    "path/filepath"
    "k8s.io/client-go/tools/clientcmd"
    "k8s.io/client-go/kubernetes"
    metav1 "k8s.io/apimachinery/pkg/apis/meta/v1"
    appsv1 "k8s.io/api/apps/v1"
    corev1 "k8s.io/api/core/v1"
)

// %% [markdown]
// ### Authentication
//
// Handles configuration-based auth (`~/.kube/config`) for out-of-cluster, i.e. how `kubectl` works
// In-cluster auth relies on credentials being injected into a running pod from within the cluster
//
// ```go
// config, err := rest.InClusterConfig()
// ```

// %%
func getKubeClient() *kubernetes.Clientset {
    home, _ := os.UserHomeDir()
    kubeConfigPath := filepath.Join(home, ".kube", "config")

    config, err := clientcmd.BuildConfigFromFlags("", kubeConfigPath)
    if err != nil {
        panic(err)
    }
    client := kubernetes.NewForConfigOrDie(config)
    return client
}

// %% [markdown]
// ### List Resources

// %%
%%
client := getKubeClient()
pods, _ := client.CoreV1().Pods("insights-agent").List(context.TODO(), metav1.ListOptions{})
for _, pod := range pods.Items {
	fmt.Println(pod)
}
// Out:
// {{ } {insights-agent-insights-right-sizer-controller-544c6bd8f6-dtf2p insights-agent-insights-right-sizer-controller-544c6bd8f6- insights-agent  a278ef2f-81ff-40e4-aae5-b38fc4a9bf44 227795 0 2024-02-16 10:34:36 -0600 CST <nil> <nil> map[app.kubernetes.io/component:controller app.kubernetes.io/instance:insights-agent app.kubernetes.io/name:insights-right-sizer pod-template-hash:544c6bd8f6] map[] [{apps/v1 ReplicaSet insights-agent-insights-right-sizer-controller-544c6bd8f6 23c6e32e-34d8-488d-8fc2-a8af3c0770bb 0x1400068f157 0x1400068f158}] [] [{kube-controller-manager Update v1 2024-02-16 10:34:36 -0600 CST FieldsV1 {"f:metadata":{"f:generateName":{},"f:labels":{".":{},"f:app.kubernetes.io/component":{},"f:app.kubernetes.io/instance":{},"f:app.kubernetes.io/name":{},"f:pod-template-hash":{}},"f:ownerReferences":{".":{},"k:{\"uid\":\"23c6e32e-34d8-488d-8fc2-a8af3c0770bb\"}":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"insights-right-sizer\"}":{".":{},"f:command":{},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:resizePolicy":{},"f:resources":{".":{},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:readOnlyRootFilesystem":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{},"f:volumeMounts":{".":{},"k:{\"mountPath\":\"/opt/app/config.yaml\"}":{".":{},"f:mountPath":{},"f:name":{},"f:readOnly":{},"f:subPath":{}}}}},"f:dnsPolicy":{},"f:enableServiceLinks":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{".":{},"f:seccompProfile":{".":{},"f:type":{}}},"f:serviceAccount":{},"f:serviceAccountName":{},"f:terminationGracePeriodSeconds":{},"f:volumes":{".":{},"k:{\"name\":\"config\"}":{".":{},"f:configMap":{".":{},"f:defaultMode":{},"f:name":{}},"f:name":{}}}}} } {kubelet Update v1 2024-02-19 11:56:35 -0600 CST FieldsV1 {"f:status":{"f:conditions":{"k:{\"type\":\"ContainersReady\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Initialized\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"PodReadyToStartContainers\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Ready\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}}},"f:containerStatuses":{},"f:hostIP":{},"f:hostIPs":{},"f:phase":{},"f:podIP":{},"f:podIPs":{".":{},"k:{\"ip\":\"10.244.0.3\"}":{".":{},"f:ip":{}}},"f:startTime":{}}} status}]} {[{config {nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil &ConfigMapVolumeSource{LocalObjectReference:LocalObjectReference{Name:insights-agent-insights-right-sizer,},Items:[]KeyToPath{},DefaultMode:*420,Optional:nil,} nil nil nil nil nil nil nil nil nil nil}} {kube-api-access-55b6b {nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil &ProjectedVolumeSource{Sources:[]VolumeProjection{VolumeProjection{Secret:nil,DownwardAPI:nil,ConfigMap:nil,ServiceAccountToken:&ServiceAccountTokenProjection{Audience:,ExpirationSeconds:*3607,Path:token,},ClusterTrustBundle:nil,},VolumeProjection{Secret:nil,DownwardAPI:nil,ConfigMap:&ConfigMapProjection{LocalObjectReference:LocalObjectReference{Name:kube-root-ca.crt,},Items:[]KeyToPath{KeyToPath{Key:ca.crt,Path:ca.crt,Mode:nil,},},Optional:nil,},ServiceAccountToken:nil,ClusterTrustBundle:nil,},VolumeProjection{Secret:nil,DownwardAPI:&DownwardAPIProjection{Items:[]DownwardAPIVolumeFile{DownwardAPIVolumeFile{Path:namespace,FieldRef:&ObjectFieldSelector{APIVersion:v1,FieldPath:metadata.namespace,},ResourceFieldRef:nil,Mode:nil,},},},ConfigMap:nil,ServiceAccountToken:nil,ClusterTrustBundle:nil,},},DefaultMode:*420,} nil nil nil nil nil}}] [] [{insights-right-sizer quay.io/fairwinds/insights-right-sizer:v0.0.2-dev [/insights-right-sizer controller -v2 --on-by-default=true --config /opt/app/config.yaml] []  [] ...
// {{ } {insights-agent-kube-state-metrics-6bcfd78546-k4zq6 insights-agent-kube-state-metrics-6bcfd78546- insights-agent  39510fd1-4704-40da-9c3a-62aaa9aa9c0a 227844 0 2024-02-16 10:34:36 -0600 CST <nil> <nil> map[app.kubernetes.io/component:metrics app.kubernetes.io/instance:insights-agent app.kubernetes.io/managed-by:Helm app.kubernetes.io/name:kube-state-metrics app.kubernetes.io/part-of:kube-state-metrics app.kubernetes.io/version:2.10.1 helm.sh/chart:kube-state-metrics-5.15.2 pod-template-hash:6bcfd78546] map[] [{apps/v1 ReplicaSet insights-agent-kube-state-metrics-6bcfd78546 814c7178-9596-4895-b5cd-68ae20a5033b 0x1400068f467 0x1400068f468}] [] [{kube-controller-manager Update v1 2024-02-16 10:34:36 -0600 CST FieldsV1 {"f:metadata":{"f:generateName":{},"f:labels":{".":{},"f:app.kubernetes.io/component":{},"f:app.kubernetes.io/instance":{},"f:app.kubernetes.io/managed-by":{},"f:app.kubernetes.io/name":{},"f:app.kubernetes.io/part-of":{},"f:app.kubernetes.io/version":{},"f:helm.sh/chart":{},"f:pod-template-hash":{}},"f:ownerReferences":{".":{},"k:{\"uid\":\"814c7178-9596-4895-b5cd-68ae20a5033b\"}":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"kube-state-metrics\"}":{".":{},"f:args":{},"f:image":{},"f:imagePullPolicy":{},"f:livenessProbe":{".":{},"f:failureThreshold":{},"f:httpGet":{".":{},"f:path":{},"f:port":{},"f:scheme":{}},"f:initialDelaySeconds":{},"f:periodSeconds":{},"f:successThreshold":{},"f:timeoutSeconds":{}},"f:name":{},"f:ports":{".":{},"k:{\"containerPort\":8080,\"protocol\":\"TCP\"}":{".":{},"f:containerPort":{},"f:name":{},"f:protocol":{}}},"f:readinessProbe":{".":{},"f:failureThreshold":{},"f:httpGet":{".":{},"f:path":{},"f:port":{},"f:scheme":{}},"f:initialDelaySeconds":{},"f:periodSeconds":{},"f:successThreshold":{},"f:timeoutSeconds":{}},"f:resizePolicy":{},"f:resources":{".":{},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:readOnlyRootFilesystem":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{}}},"f:dnsPolicy":{},"f:enableServiceLinks":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{".":{},"f:fsGroup":{},"f:runAsGroup":{},"f:runAsNonRoot":{},"f:runAsUser":{},"f:seccompProfile":{".":{},"f:type":{}}},"f:serviceAccount":{},"f:serviceAccountName":{},"f:terminationGracePeriodSeconds":{}}} } {kubelet Update v1 2024-02-19 11:56:46 -0600 CST FieldsV1 {"f:status":{"f:conditions":{"k:{\"type\":\"ContainersReady\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Initialized\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"PodReadyToStartContainers\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Ready\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}}},"f:containerStatuses":{},"f:hostIP":{},"f:hostIPs":{},"f:phase":{},"f:podIP":{},"f:podIPs":{".":{},"k:{\"ip\":\"10.244.0.19\"}":{".":{},"f:ip":{}}},"f:startTime":{}}} status}]} {[{kube-api-access-zmtcw {nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil &ProjectedVolumeSource{Sources:[]VolumeProjection{VolumeProjection{Secret:nil,DownwardAPI:nil,ConfigMap:nil,ServiceAccountToken:&ServiceAccountTokenProjection{Audience:,ExpirationSeconds:*3607,Path:token,},ClusterTrustBundle:nil,},VolumeProjection{Secret:nil,DownwardAPI:nil,ConfigMap:&ConfigMapProjection{LocalObjectReference:LocalObjectReference{Name:kube-root-ca.crt,},Items:[]KeyToPath{KeyToPath{Key:ca.crt,Path:ca.crt,Mode:nil,},},Optional:nil,},ServiceAccountToken:nil,ClusterTrustBundle:nil,},VolumeProjection{Secret:nil,DownwardAPI:&DownwardAPIProjection{Items:[]DownwardAPIVolumeFile{DownwardAPIVolumeFile{Path:namespace,FieldRef:&ObjectFieldSelector{APIVersion:v1,FieldPath:metadata.namespace,},ResourceFieldRef:nil,Mode:nil,},},},ConfigMap:nil,ServiceAccount ...
// {{ } {insights-agent-vpa-admission-controller-54867bc4bd-2c59x insights-agent-vpa-admission-controller-54867bc4bd- insights-agent  385b2de1-17f9-4b65-9c42-d28583b7f69e 227826 0 2024-02-16 10:34:36 -0600 CST <nil> <nil> map[app.kubernetes.io/component:admission-controller app.kubernetes.io/instance:insights-agent app.kubernetes.io/name:vpa pod-template-hash:54867bc4bd] map[] [{apps/v1 ReplicaSet insights-agent-vpa-admission-controller-54867bc4bd cfc9d3bd-dc31-42f5-a113-bee11f362ac5 0x1400068f75a 0x1400068f75b}] [] [{kube-controller-manager Update v1 2024-02-16 10:34:36 -0600 CST FieldsV1 {"f:metadata":{"f:generateName":{},"f:labels":{".":{},"f:app.kubernetes.io/component":{},"f:app.kubernetes.io/instance":{},"f:app.kubernetes.io/name":{},"f:pod-template-hash":{}},"f:ownerReferences":{".":{},"k:{\"uid\":\"cfc9d3bd-dc31-42f5-a113-bee11f362ac5\"}":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"vpa\"}":{".":{},"f:args":{},"f:env":{".":{},"k:{\"name\":\"NAMESPACE\"}":{".":{},"f:name":{},"f:valueFrom":{".":{},"f:fieldRef":{}}}},"f:image":{},"f:imagePullPolicy":{},"f:livenessProbe":{".":{},"f:failureThreshold":{},"f:httpGet":{".":{},"f:path":{},"f:port":{},"f:scheme":{}},"f:periodSeconds":{},"f:successThreshold":{},"f:timeoutSeconds":{}},"f:name":{},"f:ports":{".":{},"k:{\"containerPort\":8000,\"protocol\":\"TCP\"}":{".":{},"f:containerPort":{},"f:name":{},"f:protocol":{}},"k:{\"containerPort\":8944,\"protocol\":\"TCP\"}":{".":{},"f:containerPort":{},"f:name":{},"f:protocol":{}}},"f:readinessProbe":{".":{},"f:failureThreshold":{},"f:httpGet":{".":{},"f:path":{},"f:port":{},"f:scheme":{}},"f:periodSeconds":{},"f:successThreshold":{},"f:timeoutSeconds":{}},"f:resizePolicy":{},"f:resources":{".":{},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{},"f:volumeMounts":{".":{},"k:{\"mountPath\":\"/etc/tls-certs\"}":{".":{},"f:mountPath":{},"f:name":{},"f:readOnly":{}}}}},"f:dnsPolicy":{},"f:enableServiceLinks":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{".":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:serviceAccount":{},"f:serviceAccountName":{},"f:terminationGracePeriodSeconds":{},"f:volumes":{".":{},"k:{\"name\":\"tls-certs\"}":{".":{},"f:name":{},"f:secret":{".":{},"f:defaultMode":{},"f:secretName":{}}}}}} } {kubelet Update v1 2024-02-19 11:56:38 -0600 CST FieldsV1 {"f:status":{"f:conditions":{"k:{\"type\":\"ContainersReady\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Initialized\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"PodReadyToStartContainers\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Ready\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}}},"f:containerStatuses":{},"f:hostIP":{},"f:hostIPs":{},"f:phase":{},"f:podIP":{},"f:podIPs":{".":{},"k:{\"ip\":\"10.244.0.6\"}":{".":{},"f:ip":{}}},"f:startTime":{}}} status}]} {[{tls-certs {nil nil nil nil nil &SecretVolumeSource{SecretName:insights-agent-vpa-tls-secret,Items:[]KeyToPath{},DefaultMode:*420,Optional:nil,} nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil}} {kube-api-access-2d9pj {nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil &ProjectedVolumeSource{Sources:[]VolumeProjection{VolumeProjection{Secret:nil,DownwardAPI:nil,ConfigMap:nil,ServiceAccountToken:&ServiceAccountTokenProjection{Audience:,ExpirationSeconds:*3607,Path:token,},ClusterTrustBundle:nil,},VolumeProjection{Secret:nil,DownwardAPI:nil,ConfigMap:&ConfigMapProjection{LocalObjectReference:LocalObjectReference{Name:kube-root-ca.crt,},Items:[]KeyToPath{KeyToPath{Key:ca.crt,Path:ca.crt,Mode:nil,},},Optional:nil,},ServiceAccountToken:nil,ClusterTrustBundle:nil,},VolumeProjection{Secret:nil,DownwardAPI:&DownwardAPIProjection{Items:[]Downwa ...
// {{ } {insights-agent-vpa-recommender-f55b65c8f-rkbvd insights-agent-vpa-recommender-f55b65c8f- insights-agent  209f5abf-8a0e-47a6-bd52-62c76fc7fa88 227825 0 2024-02-16 12:01:49 -0600 CST <nil> <nil> map[app.kubernetes.io/component:recommender app.kubernetes.io/instance:insights-agent app.kubernetes.io/name:vpa pod-template-hash:f55b65c8f] map[] [{apps/v1 ReplicaSet insights-agent-vpa-recommender-f55b65c8f 5a82b54d-78a8-42f7-b505-97e379490da7 0x1400068fa7a 0x1400068fa7b}] [] [{kube-controller-manager Update v1 2024-02-16 12:01:48 -0600 CST FieldsV1 {"f:metadata":{"f:generateName":{},"f:labels":{".":{},"f:app.kubernetes.io/component":{},"f:app.kubernetes.io/instance":{},"f:app.kubernetes.io/name":{},"f:pod-template-hash":{}},"f:ownerReferences":{".":{},"k:{\"uid\":\"5a82b54d-78a8-42f7-b505-97e379490da7\"}":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"vpa\"}":{".":{},"f:args":{},"f:envFrom":{},"f:image":{},"f:imagePullPolicy":{},"f:livenessProbe":{".":{},"f:failureThreshold":{},"f:httpGet":{".":{},"f:path":{},"f:port":{},"f:scheme":{}},"f:periodSeconds":{},"f:successThreshold":{},"f:timeoutSeconds":{}},"f:name":{},"f:ports":{".":{},"k:{\"containerPort\":8942,\"protocol\":\"TCP\"}":{".":{},"f:containerPort":{},"f:name":{},"f:protocol":{}}},"f:readinessProbe":{".":{},"f:failureThreshold":{},"f:httpGet":{".":{},"f:path":{},"f:port":{},"f:scheme":{}},"f:periodSeconds":{},"f:successThreshold":{},"f:timeoutSeconds":{}},"f:resizePolicy":{},"f:resources":{".":{},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:readOnlyRootFilesystem":{},"f:runAsUser":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{}}},"f:dnsPolicy":{},"f:enableServiceLinks":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{".":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:serviceAccount":{},"f:serviceAccountName":{},"f:terminationGracePeriodSeconds":{}}} } {kubelet Update v1 2024-02-19 11:56:37 -0600 CST FieldsV1 {"f:status":{"f:conditions":{"k:{\"type\":\"ContainersReady\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Initialized\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"PodReadyToStartContainers\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Ready\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}}},"f:containerStatuses":{},"f:hostIP":{},"f:hostIPs":{},"f:phase":{},"f:podIP":{},"f:podIPs":{".":{},"k:{\"ip\":\"10.244.0.5\"}":{".":{},"f:ip":{}}},"f:startTime":{}}} status}]} {[{kube-api-access-zrxh5 {nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil &ProjectedVolumeSource{Sources:[]VolumeProjection{VolumeProjection{Secret:nil,DownwardAPI:nil,ConfigMap:nil,ServiceAccountToken:&ServiceAccountTokenProjection{Audience:,ExpirationSeconds:*3607,Path:token,},ClusterTrustBundle:nil,},VolumeProjection{Secret:nil,DownwardAPI:nil,ConfigMap:&ConfigMapProjection{LocalObjectReference:LocalObjectReference{Name:kube-root-ca.crt,},Items:[]KeyToPath{KeyToPath{Key:ca.crt,Path:ca.crt,Mode:nil,},},Optional:nil,},ServiceAccountToken:nil,ClusterTrustBundle:nil,},VolumeProjection{Secret:nil,DownwardAPI:&DownwardAPIProjection{Items:[]DownwardAPIVolumeFile{DownwardAPIVolumeFile{Path:namespace,FieldRef:&ObjectFieldSelector{APIVersion:v1,FieldPath:metadata.namespace,},ResourceFieldRef:nil,Mode:nil,},},},ConfigMap:nil,ServiceAccountToken:nil,ClusterTrustBundle:nil,},},DefaultMode:*420,} nil nil nil nil nil}}] [] [{vpa quay.io/fairwinds/vpa-recommender:master [] [--pod-recommendation-min-cpu-millicores=15 --pod-recommendation-min-memory-mb=100 --recommender-interval=1m0s --use-insights-recommender=true --v=10]  [{metrics 0 8942 TCP }] [{ nil &SecretEnvSource{LocalObjectReference:LocalObjectReference{Name:insights-agent-token,},Optional ...
// {{ } {insights-agent-vpa-updater-6c87d5654c-9nhq7 insights-agent-vpa-updater-6c87d5654c- insights-agent  a3dea94e-fb3b-4dfd-8dbd-8d730bc7b2e9 227817 0 2024-02-16 10:34:36 -0600 CST <nil> <nil> map[app.kubernetes.io/component:updater app.kubernetes.io/instance:insights-agent app.kubernetes.io/name:vpa pod-template-hash:6c87d5654c] map[] [{apps/v1 ReplicaSet insights-agent-vpa-updater-6c87d5654c a55544bb-0f8c-4be1-81f0-89d50eaa5e4e 0x1400068fd57 0x1400068fd58}] [] [{kube-controller-manager Update v1 2024-02-16 10:34:36 -0600 CST FieldsV1 {"f:metadata":{"f:generateName":{},"f:labels":{".":{},"f:app.kubernetes.io/component":{},"f:app.kubernetes.io/instance":{},"f:app.kubernetes.io/name":{},"f:pod-template-hash":{}},"f:ownerReferences":{".":{},"k:{\"uid\":\"a55544bb-0f8c-4be1-81f0-89d50eaa5e4e\"}":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"vpa\"}":{".":{},"f:env":{".":{},"k:{\"name\":\"NAMESPACE\"}":{".":{},"f:name":{},"f:valueFrom":{".":{},"f:fieldRef":{}}}},"f:image":{},"f:imagePullPolicy":{},"f:livenessProbe":{".":{},"f:failureThreshold":{},"f:httpGet":{".":{},"f:path":{},"f:port":{},"f:scheme":{}},"f:periodSeconds":{},"f:successThreshold":{},"f:timeoutSeconds":{}},"f:name":{},"f:ports":{".":{},"k:{\"containerPort\":8943,\"protocol\":\"TCP\"}":{".":{},"f:containerPort":{},"f:name":{},"f:protocol":{}}},"f:readinessProbe":{".":{},"f:failureThreshold":{},"f:httpGet":{".":{},"f:path":{},"f:port":{},"f:scheme":{}},"f:periodSeconds":{},"f:successThreshold":{},"f:timeoutSeconds":{}},"f:resizePolicy":{},"f:resources":{".":{},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{}}},"f:dnsPolicy":{},"f:enableServiceLinks":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{".":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:serviceAccount":{},"f:serviceAccountName":{},"f:terminationGracePeriodSeconds":{}}} } {kubelet Update v1 2024-02-19 11:56:37 -0600 CST FieldsV1 {"f:status":{"f:conditions":{"k:{\"type\":\"ContainersReady\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Initialized\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"PodReadyToStartContainers\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Ready\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}}},"f:containerStatuses":{},"f:hostIP":{},"f:hostIPs":{},"f:phase":{},"f:podIP":{},"f:podIPs":{".":{},"k:{\"ip\":\"10.244.0.4\"}":{".":{},"f:ip":{}}},"f:startTime":{}}} status}]} {[{kube-api-access-tn6zn {nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil &ProjectedVolumeSource{Sources:[]VolumeProjection{VolumeProjection{Secret:nil,DownwardAPI:nil,ConfigMap:nil,ServiceAccountToken:&ServiceAccountTokenProjection{Audience:,ExpirationSeconds:*3607,Path:token,},ClusterTrustBundle:nil,},VolumeProjection{Secret:nil,DownwardAPI:nil,ConfigMap:&ConfigMapProjection{LocalObjectReference:LocalObjectReference{Name:kube-root-ca.crt,},Items:[]KeyToPath{KeyToPath{Key:ca.crt,Path:ca.crt,Mode:nil,},},Optional:nil,},ServiceAccountToken:nil,ClusterTrustBundle:nil,},VolumeProjection{Secret:nil,DownwardAPI:&DownwardAPIProjection{Items:[]DownwardAPIVolumeFile{DownwardAPIVolumeFile{Path:namespace,FieldRef:&ObjectFieldSelector{APIVersion:v1,FieldPath:metadata.namespace,},ResourceFieldRef:nil,Mode:nil,},},},ConfigMap:nil,ServiceAccountToken:nil,ClusterTrustBundle:nil,},},DefaultMode:*420,} nil nil nil nil nil}}] [] [{vpa registry.k8s.io/autoscaling/vpa-updater:1.0.0 [] []  [{metrics 0 8943 TCP }] [] [{NAMESPACE  &EnvVarSource{FieldRef:&ObjectFieldSelector{APIVersion:v1,FieldPath:metadata.namespace,},ResourceFieldRef:nil,ConfigMapKeyRef:nil,SecretKeyRef:nil,}}] {map[] map[cpu:{{50 -3} {<nil>} 50m DecimalSI} memory:{{524288000 0} {<nil>} 500Mi BinarySI}] []} [{cpu NotRequired} {memory NotRequir ...
// {{ } {prometheus-metrics-28472650-574dt prometheus-metrics-28472650- insights-agent  1f40bfef-9455-446f-92db-21285b9b985f 227690 0 2024-02-19 10:10:00 -0600 CST <nil> <nil> map[app.kubernetes.io/name:prometheus-metrics app.kubernetes.io/part-of:insights-agent batch.kubernetes.io/controller-uid:fa30efff-d369-4611-a426-2712c8b5efbe batch.kubernetes.io/job-name:prometheus-metrics-28472650 controller-uid:fa30efff-d369-4611-a426-2712c8b5efbe job-name:prometheus-metrics-28472650] map[cluster-autoscaler.kubernetes.io/safe-to-evict:true] [{batch/v1 Job prometheus-metrics-28472650 fa30efff-d369-4611-a426-2712c8b5efbe 0x1400060606b 0x1400060606c}] [] [{kube-controller-manager Update v1 2024-02-19 10:10:00 -0600 CST FieldsV1 {"f:metadata":{"f:annotations":{".":{},"f:cluster-autoscaler.kubernetes.io/safe-to-evict":{}},"f:generateName":{},"f:labels":{".":{},"f:app.kubernetes.io/name":{},"f:app.kubernetes.io/part-of":{},"f:batch.kubernetes.io/controller-uid":{},"f:batch.kubernetes.io/job-name":{},"f:controller-uid":{},"f:job-name":{}},"f:ownerReferences":{".":{},"k:{\"uid\":\"fa30efff-d369-4611-a426-2712c8b5efbe\"}":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"insights-uploader\"}":{".":{},"f:command":{},"f:env":{".":{},"k:{\"name\":\"FAIRWINDS_AGENT_CHART_VERSION\"}":{".":{},"f:name":{},"f:value":{}},"k:{\"name\":\"FAIRWINDS_TOKEN\"}":{".":{},"f:name":{},"f:valueFrom":{".":{},"f:secretKeyRef":{}}},"k:{\"name\":\"POD_NAME\"}":{".":{},"f:name":{},"f:valueFrom":{".":{},"f:fieldRef":{}}},"k:{\"name\":\"SEND_FAILURES\"}":{".":{},"f:name":{},"f:value":{}}},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:resizePolicy":{},"f:resources":{".":{},"f:limits":{".":{},"f:cpu":{},"f:memory":{}},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:privileged":{},"f:readOnlyRootFilesystem":{},"f:runAsGroup":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{},"f:volumeMounts":{".":{},"k:{\"mountPath\":\"/output\"}":{".":{},"f:mountPath":{},"f:name":{}}}},"k:{\"name\":\"prometheus-metrics\"}":{".":{},"f:command":{},"f:env":{".":{},"k:{\"name\":\"PROMETHEUS_ADDRESS\"}":{".":{},"f:name":{},"f:value":{}}},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:resizePolicy":{},"f:resources":{".":{},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:privileged":{},"f:readOnlyRootFilesystem":{},"f:runAsGroup":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{},"f:volumeMounts":{".":{},"k:{\"mountPath\":\"/output\"}":{".":{},"f:mountPath":{},"f:name":{}}}}},"f:dnsPolicy":{},"f:enableServiceLinks":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{},"f:serviceAccount":{},"f:serviceAccountName":{},"f:terminationGracePeriodSeconds":{},"f:volumes":{".":{},"k:{\"name\":\"output\"}":{".":{},"f:emptyDir":{},"f:name":{}}}}} } {kubelet Update v1 2024-02-19 10:10:03 -0600 CST FieldsV1 {"f:status":{"f:conditions":{"k:{\"type\":\"ContainersReady\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:reason":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Initialized\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:reason":{},"f:status":{},"f:type":{}},"k:{\"type\":\"PodReadyToStartContainers\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Ready\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:reason":{},"f:status":{},"f:type":{}}},"f:containerStatuses":{},"f:hostIP":{},"f:hostIPs":{},"f:phase":{},"f:startTime":{}}} status}]} {[{output {nil &EmptyDirVolumeSource{Medium:,SizeLimit:<nil>,} nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil}} {kube-api-access-24ddg {nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil n ...
// {{ } {prometheus-metrics-28472660-splmp prometheus-metrics-28472660- insights-agent  8dc41d98-5d8d-4e1e-87d0-b666e2fc3474 227693 0 2024-02-19 10:20:00 -0600 CST <nil> <nil> map[app.kubernetes.io/name:prometheus-metrics app.kubernetes.io/part-of:insights-agent batch.kubernetes.io/controller-uid:7079080c-6135-4692-9994-11f29dd5800b batch.kubernetes.io/job-name:prometheus-metrics-28472660 controller-uid:7079080c-6135-4692-9994-11f29dd5800b job-name:prometheus-metrics-28472660] map[cluster-autoscaler.kubernetes.io/safe-to-evict:true] [{batch/v1 Job prometheus-metrics-28472660 7079080c-6135-4692-9994-11f29dd5800b 0x14000606483 0x14000606484}] [] [{kube-controller-manager Update v1 2024-02-19 10:20:00 -0600 CST FieldsV1 {"f:metadata":{"f:annotations":{".":{},"f:cluster-autoscaler.kubernetes.io/safe-to-evict":{}},"f:generateName":{},"f:labels":{".":{},"f:app.kubernetes.io/name":{},"f:app.kubernetes.io/part-of":{},"f:batch.kubernetes.io/controller-uid":{},"f:batch.kubernetes.io/job-name":{},"f:controller-uid":{},"f:job-name":{}},"f:ownerReferences":{".":{},"k:{\"uid\":\"7079080c-6135-4692-9994-11f29dd5800b\"}":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"insights-uploader\"}":{".":{},"f:command":{},"f:env":{".":{},"k:{\"name\":\"FAIRWINDS_AGENT_CHART_VERSION\"}":{".":{},"f:name":{},"f:value":{}},"k:{\"name\":\"FAIRWINDS_TOKEN\"}":{".":{},"f:name":{},"f:valueFrom":{".":{},"f:secretKeyRef":{}}},"k:{\"name\":\"POD_NAME\"}":{".":{},"f:name":{},"f:valueFrom":{".":{},"f:fieldRef":{}}},"k:{\"name\":\"SEND_FAILURES\"}":{".":{},"f:name":{},"f:value":{}}},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:resizePolicy":{},"f:resources":{".":{},"f:limits":{".":{},"f:cpu":{},"f:memory":{}},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:privileged":{},"f:readOnlyRootFilesystem":{},"f:runAsGroup":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{},"f:volumeMounts":{".":{},"k:{\"mountPath\":\"/output\"}":{".":{},"f:mountPath":{},"f:name":{}}}},"k:{\"name\":\"prometheus-metrics\"}":{".":{},"f:command":{},"f:env":{".":{},"k:{\"name\":\"PROMETHEUS_ADDRESS\"}":{".":{},"f:name":{},"f:value":{}}},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:resizePolicy":{},"f:resources":{".":{},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:privileged":{},"f:readOnlyRootFilesystem":{},"f:runAsGroup":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{},"f:volumeMounts":{".":{},"k:{\"mountPath\":\"/output\"}":{".":{},"f:mountPath":{},"f:name":{}}}}},"f:dnsPolicy":{},"f:enableServiceLinks":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{},"f:serviceAccount":{},"f:serviceAccountName":{},"f:terminationGracePeriodSeconds":{},"f:volumes":{".":{},"k:{\"name\":\"output\"}":{".":{},"f:emptyDir":{},"f:name":{}}}}} } {kubelet Update v1 2024-02-19 10:20:03 -0600 CST FieldsV1 {"f:status":{"f:conditions":{"k:{\"type\":\"ContainersReady\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:reason":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Initialized\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:reason":{},"f:status":{},"f:type":{}},"k:{\"type\":\"PodReadyToStartContainers\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Ready\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:reason":{},"f:status":{},"f:type":{}}},"f:containerStatuses":{},"f:hostIP":{},"f:hostIPs":{},"f:phase":{},"f:startTime":{}}} status}]} {[{output {nil &EmptyDirVolumeSource{Medium:,SizeLimit:<nil>,} nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil}} {kube-api-access-k8vqv {nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil n ...
// {{ } {prometheus-metrics-28472770-cns7t prometheus-metrics-28472770- insights-agent  1d079f2e-d318-4651-bc21-8e1b62c3b79f 229144 0 2024-02-19 12:10:00 -0600 CST <nil> <nil> map[app.kubernetes.io/name:prometheus-metrics app.kubernetes.io/part-of:insights-agent batch.kubernetes.io/controller-uid:367c1e52-3d74-4ce4-87c3-cdcaccd60887 batch.kubernetes.io/job-name:prometheus-metrics-28472770 controller-uid:367c1e52-3d74-4ce4-87c3-cdcaccd60887 job-name:prometheus-metrics-28472770] map[cluster-autoscaler.kubernetes.io/safe-to-evict:true] [{batch/v1 Job prometheus-metrics-28472770 367c1e52-3d74-4ce4-87c3-cdcaccd60887 0x140006068a3 0x140006068a4}] [] [{kube-controller-manager Update v1 2024-02-19 12:10:00 -0600 CST FieldsV1 {"f:metadata":{"f:annotations":{".":{},"f:cluster-autoscaler.kubernetes.io/safe-to-evict":{}},"f:generateName":{},"f:labels":{".":{},"f:app.kubernetes.io/name":{},"f:app.kubernetes.io/part-of":{},"f:batch.kubernetes.io/controller-uid":{},"f:batch.kubernetes.io/job-name":{},"f:controller-uid":{},"f:job-name":{}},"f:ownerReferences":{".":{},"k:{\"uid\":\"367c1e52-3d74-4ce4-87c3-cdcaccd60887\"}":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"insights-uploader\"}":{".":{},"f:command":{},"f:env":{".":{},"k:{\"name\":\"FAIRWINDS_AGENT_CHART_VERSION\"}":{".":{},"f:name":{},"f:value":{}},"k:{\"name\":\"FAIRWINDS_TOKEN\"}":{".":{},"f:name":{},"f:valueFrom":{".":{},"f:secretKeyRef":{}}},"k:{\"name\":\"POD_NAME\"}":{".":{},"f:name":{},"f:valueFrom":{".":{},"f:fieldRef":{}}},"k:{\"name\":\"SEND_FAILURES\"}":{".":{},"f:name":{},"f:value":{}}},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:resizePolicy":{},"f:resources":{".":{},"f:limits":{".":{},"f:cpu":{},"f:memory":{}},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:privileged":{},"f:readOnlyRootFilesystem":{},"f:runAsGroup":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{},"f:volumeMounts":{".":{},"k:{\"mountPath\":\"/output\"}":{".":{},"f:mountPath":{},"f:name":{}}}},"k:{\"name\":\"prometheus-metrics\"}":{".":{},"f:command":{},"f:env":{".":{},"k:{\"name\":\"PROMETHEUS_ADDRESS\"}":{".":{},"f:name":{},"f:value":{}}},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:resizePolicy":{},"f:resources":{".":{},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:privileged":{},"f:readOnlyRootFilesystem":{},"f:runAsGroup":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{},"f:volumeMounts":{".":{},"k:{\"mountPath\":\"/output\"}":{".":{},"f:mountPath":{},"f:name":{}}}}},"f:dnsPolicy":{},"f:enableServiceLinks":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{},"f:serviceAccount":{},"f:serviceAccountName":{},"f:terminationGracePeriodSeconds":{},"f:volumes":{".":{},"k:{\"name\":\"output\"}":{".":{},"f:emptyDir":{},"f:name":{}}}}} } {kubelet Update v1 2024-02-19 12:10:03 -0600 CST FieldsV1 {"f:status":{"f:conditions":{"k:{\"type\":\"ContainersReady\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:reason":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Initialized\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"PodReadyToStartContainers\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Ready\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:reason":{},"f:status":{},"f:type":{}}},"f:containerStatuses":{},"f:hostIP":{},"f:hostIPs":{},"f:phase":{},"f:podIP":{},"f:podIPs":{".":{},"k:{\"ip\":\"10.244.0.25\"}":{".":{},"f:ip":{}}},"f:startTime":{}}} status}]} {[{output {nil &EmptyDirVolumeSource{Medium:,SizeLimit:<nil>,} nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil}} {kube-api-access-tq2np {nil ni ...
// {{ } {prometheus-metrics-28472770-g442h prometheus-metrics-28472770- insights-agent  31c9bb31-3341-4d4f-bc5a-da4ca58af15b 229180 0 2024-02-19 12:10:11 -0600 CST <nil> <nil> map[app.kubernetes.io/name:prometheus-metrics app.kubernetes.io/part-of:insights-agent batch.kubernetes.io/controller-uid:367c1e52-3d74-4ce4-87c3-cdcaccd60887 batch.kubernetes.io/job-name:prometheus-metrics-28472770 controller-uid:367c1e52-3d74-4ce4-87c3-cdcaccd60887 job-name:prometheus-metrics-28472770] map[cluster-autoscaler.kubernetes.io/safe-to-evict:true] [{batch/v1 Job prometheus-metrics-28472770 367c1e52-3d74-4ce4-87c3-cdcaccd60887 0x14000606cc3 0x14000606cc4}] [] [{kube-controller-manager Update v1 2024-02-19 12:10:11 -0600 CST FieldsV1 {"f:metadata":{"f:annotations":{".":{},"f:cluster-autoscaler.kubernetes.io/safe-to-evict":{}},"f:generateName":{},"f:labels":{".":{},"f:app.kubernetes.io/name":{},"f:app.kubernetes.io/part-of":{},"f:batch.kubernetes.io/controller-uid":{},"f:batch.kubernetes.io/job-name":{},"f:controller-uid":{},"f:job-name":{}},"f:ownerReferences":{".":{},"k:{\"uid\":\"367c1e52-3d74-4ce4-87c3-cdcaccd60887\"}":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"insights-uploader\"}":{".":{},"f:command":{},"f:env":{".":{},"k:{\"name\":\"FAIRWINDS_AGENT_CHART_VERSION\"}":{".":{},"f:name":{},"f:value":{}},"k:{\"name\":\"FAIRWINDS_TOKEN\"}":{".":{},"f:name":{},"f:valueFrom":{".":{},"f:secretKeyRef":{}}},"k:{\"name\":\"POD_NAME\"}":{".":{},"f:name":{},"f:valueFrom":{".":{},"f:fieldRef":{}}},"k:{\"name\":\"SEND_FAILURES\"}":{".":{},"f:name":{},"f:value":{}}},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:resizePolicy":{},"f:resources":{".":{},"f:limits":{".":{},"f:cpu":{},"f:memory":{}},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:privileged":{},"f:readOnlyRootFilesystem":{},"f:runAsGroup":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{},"f:volumeMounts":{".":{},"k:{\"mountPath\":\"/output\"}":{".":{},"f:mountPath":{},"f:name":{}}}},"k:{\"name\":\"prometheus-metrics\"}":{".":{},"f:command":{},"f:env":{".":{},"k:{\"name\":\"PROMETHEUS_ADDRESS\"}":{".":{},"f:name":{},"f:value":{}}},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:resizePolicy":{},"f:resources":{".":{},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:privileged":{},"f:readOnlyRootFilesystem":{},"f:runAsGroup":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{},"f:volumeMounts":{".":{},"k:{\"mountPath\":\"/output\"}":{".":{},"f:mountPath":{},"f:name":{}}}}},"f:dnsPolicy":{},"f:enableServiceLinks":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{},"f:serviceAccount":{},"f:serviceAccountName":{},"f:terminationGracePeriodSeconds":{},"f:volumes":{".":{},"k:{\"name\":\"output\"}":{".":{},"f:emptyDir":{},"f:name":{}}}}} } {kubelet Update v1 2024-02-19 12:10:14 -0600 CST FieldsV1 {"f:status":{"f:conditions":{"k:{\"type\":\"ContainersReady\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:reason":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Initialized\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"PodReadyToStartContainers\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Ready\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:reason":{},"f:status":{},"f:type":{}}},"f:containerStatuses":{},"f:hostIP":{},"f:hostIPs":{},"f:phase":{},"f:podIP":{},"f:podIPs":{".":{},"k:{\"ip\":\"10.244.0.26\"}":{".":{},"f:ip":{}}},"f:startTime":{}}} status}]} {[{output {nil &EmptyDirVolumeSource{Medium:,SizeLimit:<nil>,} nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil}} {kube-api-access-sw6mw {nil ni ...
// {{ } {prometheus-metrics-28472780-49rr6 prometheus-metrics-28472780- insights-agent  8525d7d9-9070-46a6-8f95-6ec6485bfd71 230071 0 2024-02-19 12:20:11 -0600 CST <nil> <nil> map[app.kubernetes.io/name:prometheus-metrics app.kubernetes.io/part-of:insights-agent batch.kubernetes.io/controller-uid:54b0c503-2f32-403f-a8cf-0f4a8e51b054 batch.kubernetes.io/job-name:prometheus-metrics-28472780 controller-uid:54b0c503-2f32-403f-a8cf-0f4a8e51b054 job-name:prometheus-metrics-28472780] map[cluster-autoscaler.kubernetes.io/safe-to-evict:true] [{batch/v1 Job prometheus-metrics-28472780 54b0c503-2f32-403f-a8cf-0f4a8e51b054 0x140006070e3 0x140006070e4}] [] [{kube-controller-manager Update v1 2024-02-19 12:20:11 -0600 CST FieldsV1 {"f:metadata":{"f:annotations":{".":{},"f:cluster-autoscaler.kubernetes.io/safe-to-evict":{}},"f:generateName":{},"f:labels":{".":{},"f:app.kubernetes.io/name":{},"f:app.kubernetes.io/part-of":{},"f:batch.kubernetes.io/controller-uid":{},"f:batch.kubernetes.io/job-name":{},"f:controller-uid":{},"f:job-name":{}},"f:ownerReferences":{".":{},"k:{\"uid\":\"54b0c503-2f32-403f-a8cf-0f4a8e51b054\"}":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"insights-uploader\"}":{".":{},"f:command":{},"f:env":{".":{},"k:{\"name\":\"FAIRWINDS_AGENT_CHART_VERSION\"}":{".":{},"f:name":{},"f:value":{}},"k:{\"name\":\"FAIRWINDS_TOKEN\"}":{".":{},"f:name":{},"f:valueFrom":{".":{},"f:secretKeyRef":{}}},"k:{\"name\":\"POD_NAME\"}":{".":{},"f:name":{},"f:valueFrom":{".":{},"f:fieldRef":{}}},"k:{\"name\":\"SEND_FAILURES\"}":{".":{},"f:name":{},"f:value":{}}},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:resizePolicy":{},"f:resources":{".":{},"f:limits":{".":{},"f:cpu":{},"f:memory":{}},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:privileged":{},"f:readOnlyRootFilesystem":{},"f:runAsGroup":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{},"f:volumeMounts":{".":{},"k:{\"mountPath\":\"/output\"}":{".":{},"f:mountPath":{},"f:name":{}}}},"k:{\"name\":\"prometheus-metrics\"}":{".":{},"f:command":{},"f:env":{".":{},"k:{\"name\":\"PROMETHEUS_ADDRESS\"}":{".":{},"f:name":{},"f:value":{}}},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:resizePolicy":{},"f:resources":{".":{},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:privileged":{},"f:readOnlyRootFilesystem":{},"f:runAsGroup":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{},"f:volumeMounts":{".":{},"k:{\"mountPath\":\"/output\"}":{".":{},"f:mountPath":{},"f:name":{}}}}},"f:dnsPolicy":{},"f:enableServiceLinks":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{},"f:serviceAccount":{},"f:serviceAccountName":{},"f:terminationGracePeriodSeconds":{},"f:volumes":{".":{},"k:{\"name\":\"output\"}":{".":{},"f:emptyDir":{},"f:name":{}}}}} } {kubelet Update v1 2024-02-19 12:20:14 -0600 CST FieldsV1 {"f:status":{"f:conditions":{"k:{\"type\":\"ContainersReady\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:reason":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Initialized\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"PodReadyToStartContainers\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Ready\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:reason":{},"f:status":{},"f:type":{}}},"f:containerStatuses":{},"f:hostIP":{},"f:hostIPs":{},"f:phase":{},"f:podIP":{},"f:podIPs":{".":{},"k:{\"ip\":\"10.244.0.28\"}":{".":{},"f:ip":{}}},"f:startTime":{}}} status}]} {[{output {nil &EmptyDirVolumeSource{Medium:,SizeLimit:<nil>,} nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil}} {kube-api-access-tnff8 {nil ni ...
// {{ } {prometheus-metrics-28472780-kbpxs prometheus-metrics-28472780- insights-agent  088cac9e-6b04-46b5-8d54-3e891731cd99 230037 0 2024-02-19 12:20:00 -0600 CST <nil> <nil> map[app.kubernetes.io/name:prometheus-metrics app.kubernetes.io/part-of:insights-agent batch.kubernetes.io/controller-uid:54b0c503-2f32-403f-a8cf-0f4a8e51b054 batch.kubernetes.io/job-name:prometheus-metrics-28472780 controller-uid:54b0c503-2f32-403f-a8cf-0f4a8e51b054 job-name:prometheus-metrics-28472780] map[cluster-autoscaler.kubernetes.io/safe-to-evict:true] [{batch/v1 Job prometheus-metrics-28472780 54b0c503-2f32-403f-a8cf-0f4a8e51b054 0x14000607503 0x14000607504}] [] [{kube-controller-manager Update v1 2024-02-19 12:20:00 -0600 CST FieldsV1 {"f:metadata":{"f:annotations":{".":{},"f:cluster-autoscaler.kubernetes.io/safe-to-evict":{}},"f:generateName":{},"f:labels":{".":{},"f:app.kubernetes.io/name":{},"f:app.kubernetes.io/part-of":{},"f:batch.kubernetes.io/controller-uid":{},"f:batch.kubernetes.io/job-name":{},"f:controller-uid":{},"f:job-name":{}},"f:ownerReferences":{".":{},"k:{\"uid\":\"54b0c503-2f32-403f-a8cf-0f4a8e51b054\"}":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"insights-uploader\"}":{".":{},"f:command":{},"f:env":{".":{},"k:{\"name\":\"FAIRWINDS_AGENT_CHART_VERSION\"}":{".":{},"f:name":{},"f:value":{}},"k:{\"name\":\"FAIRWINDS_TOKEN\"}":{".":{},"f:name":{},"f:valueFrom":{".":{},"f:secretKeyRef":{}}},"k:{\"name\":\"POD_NAME\"}":{".":{},"f:name":{},"f:valueFrom":{".":{},"f:fieldRef":{}}},"k:{\"name\":\"SEND_FAILURES\"}":{".":{},"f:name":{},"f:value":{}}},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:resizePolicy":{},"f:resources":{".":{},"f:limits":{".":{},"f:cpu":{},"f:memory":{}},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:privileged":{},"f:readOnlyRootFilesystem":{},"f:runAsGroup":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{},"f:volumeMounts":{".":{},"k:{\"mountPath\":\"/output\"}":{".":{},"f:mountPath":{},"f:name":{}}}},"k:{\"name\":\"prometheus-metrics\"}":{".":{},"f:command":{},"f:env":{".":{},"k:{\"name\":\"PROMETHEUS_ADDRESS\"}":{".":{},"f:name":{},"f:value":{}}},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:resizePolicy":{},"f:resources":{".":{},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:privileged":{},"f:readOnlyRootFilesystem":{},"f:runAsGroup":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{},"f:volumeMounts":{".":{},"k:{\"mountPath\":\"/output\"}":{".":{},"f:mountPath":{},"f:name":{}}}}},"f:dnsPolicy":{},"f:enableServiceLinks":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{},"f:serviceAccount":{},"f:serviceAccountName":{},"f:terminationGracePeriodSeconds":{},"f:volumes":{".":{},"k:{\"name\":\"output\"}":{".":{},"f:emptyDir":{},"f:name":{}}}}} } {kubelet Update v1 2024-02-19 12:20:04 -0600 CST FieldsV1 {"f:status":{"f:conditions":{"k:{\"type\":\"ContainersReady\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:reason":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Initialized\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"PodReadyToStartContainers\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Ready\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:reason":{},"f:status":{},"f:type":{}}},"f:containerStatuses":{},"f:hostIP":{},"f:hostIPs":{},"f:phase":{},"f:podIP":{},"f:podIPs":{".":{},"k:{\"ip\":\"10.244.0.27\"}":{".":{},"f:ip":{}}},"f:startTime":{}}} status}]} {[{output {nil &EmptyDirVolumeSource{Medium:,SizeLimit:<nil>,} nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil}} {kube-api-access-z9lb2 {nil ni ...
// ...
// {{ } {workloads-28472706-4b2bh workloads-28472706- insights-agent  dee8954a-c045-4951-af65-1c21bb5315b2 227728 0 2024-02-19 11:06:11 -0600 CST <nil> <nil> map[app.kubernetes.io/name:workloads app.kubernetes.io/part-of:insights-agent batch.kubernetes.io/controller-uid:10ab4021-c6c7-46b6-a29f-a2ac663d9121 batch.kubernetes.io/job-name:workloads-28472706 controller-uid:10ab4021-c6c7-46b6-a29f-a2ac663d9121 job-name:workloads-28472706] map[cluster-autoscaler.kubernetes.io/safe-to-evict:true] [{batch/v1 Job workloads-28472706 10ab4021-c6c7-46b6-a29f-a2ac663d9121 0x14000047443 0x14000047444}] [] [{kube-controller-manager Update v1 2024-02-19 11:06:11 -0600 CST FieldsV1 {"f:metadata":{"f:annotations":{".":{},"f:cluster-autoscaler.kubernetes.io/safe-to-evict":{}},"f:generateName":{},"f:labels":{".":{},"f:app.kubernetes.io/name":{},"f:app.kubernetes.io/part-of":{},"f:batch.kubernetes.io/controller-uid":{},"f:batch.kubernetes.io/job-name":{},"f:controller-uid":{},"f:job-name":{}},"f:ownerReferences":{".":{},"k:{\"uid\":\"10ab4021-c6c7-46b6-a29f-a2ac663d9121\"}":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"insights-uploader\"}":{".":{},"f:command":{},"f:env":{".":{},"k:{\"name\":\"FAIRWINDS_AGENT_CHART_VERSION\"}":{".":{},"f:name":{},"f:value":{}},"k:{\"name\":\"FAIRWINDS_TOKEN\"}":{".":{},"f:name":{},"f:valueFrom":{".":{},"f:secretKeyRef":{}}},"k:{\"name\":\"POD_NAME\"}":{".":{},"f:name":{},"f:valueFrom":{".":{},"f:fieldRef":{}}},"k:{\"name\":\"SEND_FAILURES\"}":{".":{},"f:name":{},"f:value":{}}},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:resizePolicy":{},"f:resources":{".":{},"f:limits":{".":{},"f:cpu":{},"f:memory":{}},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:privileged":{},"f:readOnlyRootFilesystem":{},"f:runAsGroup":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{},"f:volumeMounts":{".":{},"k:{\"mountPath\":\"/output\"}":{".":{},"f:mountPath":{},"f:name":{}}}},"k:{\"name\":\"workloads\"}":{".":{},"f:command":{},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:resizePolicy":{},"f:resources":{".":{},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:privileged":{},"f:readOnlyRootFilesystem":{},"f:runAsGroup":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{},"f:volumeMounts":{".":{},"k:{\"mountPath\":\"/output\"}":{".":{},"f:mountPath":{},"f:name":{}}}}},"f:dnsPolicy":{},"f:enableServiceLinks":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{},"f:serviceAccount":{},"f:serviceAccountName":{},"f:terminationGracePeriodSeconds":{},"f:volumes":{".":{},"k:{\"name\":\"output\"}":{".":{},"f:emptyDir":{},"f:name":{}}}}} } {kubelet Update v1 2024-02-19 11:06:15 -0600 CST FieldsV1 {"f:status":{"f:conditions":{"k:{\"type\":\"ContainersReady\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:reason":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Initialized\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"PodReadyToStartContainers\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Ready\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:reason":{},"f:status":{},"f:type":{}}},"f:containerStatuses":{},"f:hostIP":{},"f:hostIPs":{},"f:phase":{},"f:startTime":{}}} status}]} {[{output {nil &EmptyDirVolumeSource{Medium:,SizeLimit:<nil>,} nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil}} {kube-api-access-wgpc9 {nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil &ProjectedVolumeSource{Sources:[]VolumeProjection{VolumeProjection{Secret:nil,DownwardAPI:nil,ConfigMap:nil,ServiceAccountToken:&ServiceAccountToke ...
// {{ } {workloads-28472766-7dv7b workloads-28472766- insights-agent  129ca637-deec-4142-89ea-ddbb2955010a 228757 0 2024-02-19 12:06:00 -0600 CST <nil> <nil> map[app.kubernetes.io/name:workloads app.kubernetes.io/part-of:insights-agent batch.kubernetes.io/controller-uid:b8833d8e-4d5b-4232-acca-3101616eec4b batch.kubernetes.io/job-name:workloads-28472766 controller-uid:b8833d8e-4d5b-4232-acca-3101616eec4b job-name:workloads-28472766] map[cluster-autoscaler.kubernetes.io/safe-to-evict:true] [{batch/v1 Job workloads-28472766 b8833d8e-4d5b-4232-acca-3101616eec4b 0x14000340043 0x14000340044}] [] [{kube-controller-manager Update v1 2024-02-19 12:06:00 -0600 CST FieldsV1 {"f:metadata":{"f:annotations":{".":{},"f:cluster-autoscaler.kubernetes.io/safe-to-evict":{}},"f:generateName":{},"f:labels":{".":{},"f:app.kubernetes.io/name":{},"f:app.kubernetes.io/part-of":{},"f:batch.kubernetes.io/controller-uid":{},"f:batch.kubernetes.io/job-name":{},"f:controller-uid":{},"f:job-name":{}},"f:ownerReferences":{".":{},"k:{\"uid\":\"b8833d8e-4d5b-4232-acca-3101616eec4b\"}":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"insights-uploader\"}":{".":{},"f:command":{},"f:env":{".":{},"k:{\"name\":\"FAIRWINDS_AGENT_CHART_VERSION\"}":{".":{},"f:name":{},"f:value":{}},"k:{\"name\":\"FAIRWINDS_TOKEN\"}":{".":{},"f:name":{},"f:valueFrom":{".":{},"f:secretKeyRef":{}}},"k:{\"name\":\"POD_NAME\"}":{".":{},"f:name":{},"f:valueFrom":{".":{},"f:fieldRef":{}}},"k:{\"name\":\"SEND_FAILURES\"}":{".":{},"f:name":{},"f:value":{}}},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:resizePolicy":{},"f:resources":{".":{},"f:limits":{".":{},"f:cpu":{},"f:memory":{}},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:privileged":{},"f:readOnlyRootFilesystem":{},"f:runAsGroup":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{},"f:volumeMounts":{".":{},"k:{\"mountPath\":\"/output\"}":{".":{},"f:mountPath":{},"f:name":{}}}},"k:{\"name\":\"workloads\"}":{".":{},"f:command":{},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:resizePolicy":{},"f:resources":{".":{},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:privileged":{},"f:readOnlyRootFilesystem":{},"f:runAsGroup":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{},"f:volumeMounts":{".":{},"k:{\"mountPath\":\"/output\"}":{".":{},"f:mountPath":{},"f:name":{}}}}},"f:dnsPolicy":{},"f:enableServiceLinks":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{},"f:serviceAccount":{},"f:serviceAccountName":{},"f:terminationGracePeriodSeconds":{},"f:volumes":{".":{},"k:{\"name\":\"output\"}":{".":{},"f:emptyDir":{},"f:name":{}}}}} } {kubelet Update v1 2024-02-19 12:06:03 -0600 CST FieldsV1 {"f:status":{"f:conditions":{"k:{\"type\":\"ContainersReady\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:reason":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Initialized\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"PodReadyToStartContainers\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Ready\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:reason":{},"f:status":{},"f:type":{}}},"f:containerStatuses":{},"f:hostIP":{},"f:hostIPs":{},"f:phase":{},"f:podIP":{},"f:podIPs":{".":{},"k:{\"ip\":\"10.244.0.23\"}":{".":{},"f:ip":{}}},"f:startTime":{}}} status}]} {[{output {nil &EmptyDirVolumeSource{Medium:,SizeLimit:<nil>,} nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil}} {kube-api-access-q2689 {nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil &ProjectedVolumeSource{Sources:[]VolumeProjection{VolumeProjection ...
// {{ } {workloads-28472766-vdjkd workloads-28472766- insights-agent  e198d16a-df25-4e88-9abd-29b5280ea8e4 228793 0 2024-02-19 12:06:11 -0600 CST <nil> <nil> map[app.kubernetes.io/name:workloads app.kubernetes.io/part-of:insights-agent batch.kubernetes.io/controller-uid:b8833d8e-4d5b-4232-acca-3101616eec4b batch.kubernetes.io/job-name:workloads-28472766 controller-uid:b8833d8e-4d5b-4232-acca-3101616eec4b job-name:workloads-28472766] map[cluster-autoscaler.kubernetes.io/safe-to-evict:true] [{batch/v1 Job workloads-28472766 b8833d8e-4d5b-4232-acca-3101616eec4b 0x140003409c3 0x140003409c4}] [] [{kube-controller-manager Update v1 2024-02-19 12:06:11 -0600 CST FieldsV1 {"f:metadata":{"f:annotations":{".":{},"f:cluster-autoscaler.kubernetes.io/safe-to-evict":{}},"f:generateName":{},"f:labels":{".":{},"f:app.kubernetes.io/name":{},"f:app.kubernetes.io/part-of":{},"f:batch.kubernetes.io/controller-uid":{},"f:batch.kubernetes.io/job-name":{},"f:controller-uid":{},"f:job-name":{}},"f:ownerReferences":{".":{},"k:{\"uid\":\"b8833d8e-4d5b-4232-acca-3101616eec4b\"}":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"insights-uploader\"}":{".":{},"f:command":{},"f:env":{".":{},"k:{\"name\":\"FAIRWINDS_AGENT_CHART_VERSION\"}":{".":{},"f:name":{},"f:value":{}},"k:{\"name\":\"FAIRWINDS_TOKEN\"}":{".":{},"f:name":{},"f:valueFrom":{".":{},"f:secretKeyRef":{}}},"k:{\"name\":\"POD_NAME\"}":{".":{},"f:name":{},"f:valueFrom":{".":{},"f:fieldRef":{}}},"k:{\"name\":\"SEND_FAILURES\"}":{".":{},"f:name":{},"f:value":{}}},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:resizePolicy":{},"f:resources":{".":{},"f:limits":{".":{},"f:cpu":{},"f:memory":{}},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:privileged":{},"f:readOnlyRootFilesystem":{},"f:runAsGroup":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{},"f:volumeMounts":{".":{},"k:{\"mountPath\":\"/output\"}":{".":{},"f:mountPath":{},"f:name":{}}}},"k:{\"name\":\"workloads\"}":{".":{},"f:command":{},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:resizePolicy":{},"f:resources":{".":{},"f:requests":{".":{},"f:cpu":{},"f:memory":{}}},"f:securityContext":{".":{},"f:allowPrivilegeEscalation":{},"f:capabilities":{".":{},"f:drop":{}},"f:privileged":{},"f:readOnlyRootFilesystem":{},"f:runAsGroup":{},"f:runAsNonRoot":{},"f:runAsUser":{}},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{},"f:volumeMounts":{".":{},"k:{\"mountPath\":\"/output\"}":{".":{},"f:mountPath":{},"f:name":{}}}}},"f:dnsPolicy":{},"f:enableServiceLinks":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{},"f:serviceAccount":{},"f:serviceAccountName":{},"f:terminationGracePeriodSeconds":{},"f:volumes":{".":{},"k:{\"name\":\"output\"}":{".":{},"f:emptyDir":{},"f:name":{}}}}} } {kubelet Update v1 2024-02-19 12:06:14 -0600 CST FieldsV1 {"f:status":{"f:conditions":{"k:{\"type\":\"ContainersReady\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:reason":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Initialized\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"PodReadyToStartContainers\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Ready\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:reason":{},"f:status":{},"f:type":{}}},"f:containerStatuses":{},"f:hostIP":{},"f:hostIPs":{},"f:phase":{},"f:podIP":{},"f:podIPs":{".":{},"k:{\"ip\":\"10.244.0.24\"}":{".":{},"f:ip":{}}},"f:startTime":{}}} status}]} {[{output {nil &EmptyDirVolumeSource{Medium:,SizeLimit:<nil>,} nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil}} {kube-api-access-6k2wj {nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil nil &ProjectedVolumeSource{Sources:[]VolumeProjection{VolumeProjection ...

// %% [markdown]
// ## Labels

// %%
func labelDeployment(client *kubernetes.Clientset, namespace string, deployment string) error {
	ctx := context.TODO()
	deploy, err := client.AppsV1().Deployments(namespace).Get(ctx, deployment, metav1.GetOptions{})
	if err != nil {
		panic(err)
	}
	fmt.Println(deploy.Labels)
	deployLabels := deploy.Labels
	if deployLabels == nil {
		deployLabels = make(map[string]string)
	}
	deployLabels["fairwinds.com/demo"] = "true"
	deploy.Labels = deployLabels
	deploy, err = client.AppsV1().Deployments(namespace).Update(ctx, deploy, metav1.UpdateOptions{})
	return err
}

// %%
%%
client := getKubeClient()
err := labelDeployment(client, "default", "nginx-deployment")
if err != nil {
	panic(err)
}

ctx := context.TODO()
deploy, err := client.AppsV1().Deployments("default").List(ctx, metav1.ListOptions{
	LabelSelector: "fairwinds.com/demo=true",
})
if err != nil {
	panic(err)
}

fmt.Println(deploy)
// Out:
// map[fairwinds.com/demo:true]
// &DeploymentList{ListMeta:{ 232602  <nil>},Items:[]Deployment{Deployment{ObjectMeta:{nginx-deployment  default  eb65bde0-9624-480e-8de0-5eaa8ca95e61 232300 2 2024-02-12 13:34:52 -0600 CST <nil> <nil> map[fairwinds.com/demo:true] map[deployment.kubernetes.io/revision:2 kubectl.kubernetes.io/last-applied-configuration:{"apiVersion":"apps/v1","kind":"Deployment","metadata":{"annotations":{},"name":"nginx-deployment","namespace":"default"},"spec":{"replicas":2,"selector":{"matchLabels":{"app":"nginx"}},"template":{"metadata":{"labels":{"app":"nginx"}},"spec":{"containers":[{"image":"nginx:1.14.2","name":"nginx","ports":[{"containerPort":80}]}]}}}}
// ] [] [] [{kubectl-client-side-apply Update apps/v1 2024-02-12 13:34:52 -0600 CST FieldsV1 {"f:metadata":{"f:annotations":{".":{},"f:kubectl.kubernetes.io/last-applied-configuration":{}}},"f:spec":{"f:progressDeadlineSeconds":{},"f:replicas":{},"f:revisionHistoryLimit":{},"f:selector":{},"f:strategy":{"f:rollingUpdate":{".":{},"f:maxSurge":{},"f:maxUnavailable":{}},"f:type":{}},"f:template":{"f:metadata":{"f:labels":{".":{},"f:app":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"nginx\"}":{".":{},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:ports":{".":{},"k:{\"containerPort\":80,\"protocol\":\"TCP\"}":{".":{},"f:containerPort":{},"f:protocol":{}}},"f:resources":{},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{}}},"f:dnsPolicy":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{},"f:terminationGracePeriodSeconds":{}}}}} } {kubectl-edit Update apps/v1 2024-02-12 13:39:42 -0600 CST FieldsV1 {"f:spec":{"f:template":{"f:spec":{"f:containers":{"k:{\"name\":\"nginx\"}":{"f:resources":{"f:requests":{".":{},"f:cpu":{}}}}}}}}} } {kube-controller-manager Update apps/v1 2024-02-12 13:39:45 -0600 CST FieldsV1 {"f:metadata":{"f:annotations":{"f:deployment.kubernetes.io/revision":{}}},"f:status":{"f:availableReplicas":{},"f:conditions":{".":{},"k:{\"type\":\"Available\"}":{".":{},"f:lastTransitionTime":{},"f:lastUpdateTime":{},"f:message":{},"f:reason":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Progressing\"}":{".":{},"f:lastTransitionTime":{},"f:lastUpdateTime":{},"f:message":{},"f:reason":{},"f:status":{},"f:type":{}}},"f:observedGeneration":{},"f:readyReplicas":{},"f:replicas":{},"f:updatedReplicas":{}}} status} {gonb_fb2dc6fa Update apps/v1 2024-02-19 12:43:04 -0600 CST FieldsV1 {"f:metadata":{"f:labels":{".":{},"f:fairwinds.com/demo":{}}}} }]},Spec:DeploymentSpec{Replicas:*2,Selector:&v1.LabelSelector{MatchLabels:map[string]string{app: nginx,},MatchExpressions:[]LabelSelectorRequirement{},},Template:{{      0 0001-01-01 00:00:00 +0000 UTC <nil> <nil> map[app:nginx] map[] [] [] []} {[] [] [{nginx nginx:1.14.2 [] []  [{ 0 80 TCP }] [] [] {map[] map[cpu:{{100 -3} {<nil>} 100m DecimalSI}] []} [] <nil> [] [] nil nil nil nil /dev/termination-log File IfNotPresent nil false false false}] [] Always 0x140004986b8 <nil> ClusterFirst map[]   <nil>  false false false <nil> PodSecurityContext{SELinuxOptions:nil,RunAsUser:nil,RunAsNonRoot:nil,SupplementalGroups:[],FSGroup:nil,RunAsGroup:nil,Sysctls:[]Sysctl{},WindowsOptions:nil,FSGroupChangePolicy:nil,SeccompProfile:nil,} []   nil default-scheduler [] []  <nil> nil [] <nil> <nil> <nil> map[] [] <nil> nil <nil> [] []}},Strategy:DeploymentStrategy{Type:RollingUpdate,RollingUpdate:&RollingUpdateDeployment{MaxUnavailable:25%,MaxSurge:25%,},},MinReadySeconds:0,RevisionHistoryLimit:*10,Paused:false,ProgressDeadlineSeconds:*600,},Status:DeploymentStatus{ObservedGeneration:2,Replicas:2,UpdatedReplicas:2,AvailableReplicas:2,UnavailableReplicas:0,Conditions:[]DeploymentCondition{DeploymentCondition{Type:Available,Status:True,Reason:MinimumReplicasAvailable,Message:Deployment has minimum availability.,LastUpdateTime:2024-02-12 13:34:53 -0600 CST,LastTransitionTime:2024-02-12 13:34:53 -0600 CST,},DeploymentCondition{Type:Progressing,Status:True,Reason:NewReplicaSetAvailable,Message:ReplicaSet "nginx-deployment-7cb7b6d557" has successfully progressed.,LastUpdateTime:2024-02-12 13:39:45 -0600 CST,LastTransitionTime:2024-02-12 13:34:52 -0600 CST,},},ReadyReplicas:2,CollisionCount:nil,},},},}

// %% [markdown]
// ## Create a Pod!

// %%
func createPod(client *kubernetes.Clientset) error {
	ctx := context.TODO()

	pod := &corev1.Pod{
        ObjectMeta: metav1.ObjectMeta{
            Name:      "test-pod",
            Namespace: "default",
            Labels: map[string]string{
                "app": "test-pod",
            },
        },
        Spec: corev1.PodSpec{
            Containers: []corev1.Container{
                {
                    Name:            "busybox",
                    Image:           "busybox",
                    ImagePullPolicy: corev1.PullIfNotPresent,
                    Command: []string{
                        "sleep",
                        "3600",
                    },
                },
            },
        },
    }

	if _, err := client.CoreV1().Pods("default").Create(ctx, pod, metav1.CreateOptions{}); err != nil {
		return err
	} else {
		return nil
	}
}

// %%
%%
client := getKubeClient()
err := createPod(client)
if err != nil {
	panic(err)
}

// %% [markdown]
// # Dynamic
//
// Can perform generic operations on arbitrary K8S API objects
//
// * `FilteredDynamicSharedInformerFactory`: watch `Unstructured` objects with `AddFunc/UpdateFunc/DeleteFunc` and handle with event handlers
// * shared caching
//
// examples of dynamic client in https://github.com/FairwindsOps/insights-plugins/tree/main/realtime-reporter/pkg
//
// ![alt text](media/informers.png "Informers")

// %% [markdown]
// ## Informer Interface
//
// ```go
// type Informer interface {
// 	AddEventHandler(handler handlers.EventHandler)
// 	HasSynced() bool
// 	Start(ch <-chan struct{})
// }
// ```
//
// ```go
// // AddEventHandler adds the handler to each namespaced informer
// func (i *multiResourceInformer) AddEventHandler(handler handlers.EventHandler) {
// 	for _, ki := range i.resourceToInformer {
// 		for kind, informer := range ki {
// 			informer.AddEventHandler(handler(kind))
// 		}
// 	}
// }
//
// // HasSynced checks if each namespaced informer has synced
// func (i *multiResourceInformer) HasSynced() bool {
// 	for _, ki := range i.resourceToInformer {
// 		for _, informer := range ki {
// 			if ok := informer.HasSynced(); !ok {
// 				return ok
// 			}
// 		}
// 	}
//
// 	return true
// }
//
// func (i *multiResourceInformer) Start(stopCh <-chan struct{}) {
// 	for _, informer := range i.informerFactory {
// 		informer.Start(stopCh)
// 	}
// }
// ```

// %% [markdown]
// # Controllers & Operators

// %% [markdown]
// ## Controllers
//
// Built-in, monitor core k8s objects
//
// Examples:
//
// * `apps/v1/Deployment`
// * `core/v1/Pod`
// * `batch/v1/Job` `batch/v1/CronJob`

// %% [markdown]
// ## Operators
//
// Controllers that operate on custom resources (CRDs). Extends capabilities of Kubernetes
//
// Examples:
//
// * `acme.cert-manager.io/Challenge` `acme.cert-manager.io/Order` `acme.cert-manager.io/Certificate`
// * `argoproj.io/Workflow` `argoproj.io/Application` `argoproj.io/Rollout`
// * `keda.sh/ScaledOject`
// * `monitoring.grafana.com/MetricsInstance`

// %% [markdown]
// ## Frameworks
//
// * [kubebuilder](https://github.com/kubernetes-sigs/kubebuilder)
// * [operator framework](https://operatorframework.io/)
